# %%
# !nvidia-smi
# Out:
# Wed Apr 15 01:48:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   37C    P0             57W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
pip install torch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 137.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 124.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 113.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 65.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 149.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.4 MB/s eta 0:00:00
# ...

# %%
# !pip install natten==0.17.5+torch250cu124 -f https://whl.natten.org
# Out:
# Looking in links: https://whl.natten.org
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.7/474.7 MB 4.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# import os
# print(os.listdir('/content/drive/MyDrive/SP26_dementia_data/processed_data'))
# Out:
# Mounted at /content/drive

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5d8ee829-7cf3-4c72-b5fb-00257b9c29ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d8ee829-7cf3-4c72-b5fb-00257b9c29ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets list

# %%
# %cd /content/drive/MyDrive/SP26_dementia_data/SadAlzDataset
# !kaggle datasets download -d yasserhessein/dataset-alzheimer
# Out:
# /content/drive/MyDrive/SP26_dementia_data/SadAlzDataset

# %%
path = '/content/drive/MyDrive/SP26_dementia_data/SadAlzDataset/'

# %%
import zipfile
with zipfile.ZipFile(path+'dataset-alzheimer.zip', 'r') as zip_ref:
    zip_ref.extractall(path)

# %%
# !git clone --branch nathan https://github.com/bealowman/alzheimers-detection-working.git
# %cd alzheimers-detection-working/MedViTV2-main
# Out:
# fatal: destination path 'alzheimers-detection-working' already exists and is not an empty directory.
# /content/drive/MyDrive/SP26_dementia_data/SadAlzDataset/alzheimers-detection-working/MedViTV2-main

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 137.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.2 MB/s eta 0:00:00
# ...

# %%
# path_result = !find /content -name "eval.py"
# path_result
# %cd /content/alzheimers-detection-working/MedViTV2-main
# Out:
# [Errno 2] No such file or directory: '/content/alzheimers-detection-working/MedViTV2-main'
# /content/drive/MyDrive/SP26_dementia_data/SadAlzDataset/alzheimers-detection-working/MedViTV2-main

# %%
# from https://www.kaggle.com/datasets/yasserhessein/dataset-alzheimer
# !python eval.py \
  --checkpoint_path '/content/drive/MyDrive/SP26_dementia_data/alzheimers_checkpoints/MedViT_small_Dementia.pth' \
  --test_dir '/content/drive/MyDrive/SP26_dementia_data/DeepFakeScans/Combined/test' \
  --model_name 'MedViT_small' \
  --cm_save_path '/content/drive/MyDrive/SP26_dementia_data/DeepFakeScans_checkpoints'

# %%
# from https://www.kaggle.com/datasets/lukechugh/best-alzheimer-mri-dataset-99-accuracy
# !python eval.py \
  --checkpoint_path '/content/drive/MyDrive/SP26_dementia_data/alzheimers_checkpoints/MedViT_small_Dementia.pth' \
  --test_dir '/content/drive/MyDrive/SP26_dementia_data/SadAlzDataset/Alzheimer_s Dataset/train' \
  --model_name 'MedViT_small' \
  --cm_save_path '/content/drive/MyDrive/SP26_dementia_data/SadAlzDataset_checkpoints'
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Device : cuda
# Model  : MedViT_small
# Checkpoint: /content/drive/MyDrive/SP26_dementia_data/alzheimers_checkpoints/MedViT_small_Dementia.pth
# Test dir  : /content/drive/MyDrive/SP26_dementia_data/SadAlzDataset/Alzheimer_s Dataset/train
#
# initialize_weights...
# ...
