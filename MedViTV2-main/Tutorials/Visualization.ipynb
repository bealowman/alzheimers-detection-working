# %%
# !git clone https://github.com/Omid-Nejati/MedViTV2.git
# %cd /content/MedViTV2
# Out:
# Cloning into 'MedViTV2'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 195 (delta 58), reused 28 (delta 26), pack-reused 112 (from 1)
# Receiving objects: 100% (195/195), 3.87 MiB | 3.77 MiB/s, done.
# Resolving deltas: 100% (70/70), done.
# /content/MedViTV2

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.0.25)
# Collecting medmnist==3.0.2 (from -r requirements.txt (line 3))
#   Downloading medmnist-3.0.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.25.2)
# Collecting fvcore (from -r requirements.txt (line 8))
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.67.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (11.3.0)
# Collecting fire (from -r requirements.txt (line 11))
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting torchattacks (from -r requirements.txt (line 12))
#   Downloading torchattacks-3.5.1-py3-none-any.whl.metadata (927 bytes)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (0.25.0+cu128)
# Collecting grad-cam (from -r requirements.txt (line 15))
#   Downloading grad-cam-1.5.5.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 83.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 5)) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r requirements.txt (line 7)) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r requirements.txt (line 7)) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r requirements.txt (line 7)) (2026.3.3)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r requirements.txt (line 7)) (26.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r requirements.txt (line 7)) (0.5)
# Collecting yacs>=0.1.6 (from fvcore->-r requirements.txt (line 8))
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.12/dist-packages (from fvcore->-r requirements.txt (line 8)) (3.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from fvcore->-r requirements.txt (line 8)) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore->-r requirements.txt (line 8))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting requests~=2.25.1 (from torchattacks->-r requirements.txt (line 12))
#   Downloading requests-2.25.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 13)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r requirements.txt (line 13)) (1.4.2)
# Collecting ttach (from grad-cam->-r requirements.txt (line 15))
#   Downloading ttach-0.0.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from grad-cam->-r requirements.txt (line 15)) (4.13.0.92)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from grad-cam->-r requirements.txt (line 15)) (3.10.0)
# Collecting portalocker (from iopath>=0.1.7->fvcore->-r requirements.txt (line 8))
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 5)) (1.17.0)
# Collecting chardet<5,>=3.0.2 (from requests~=2.25.1->torchattacks->-r requirements.txt (line 12))
#   Downloading chardet-4.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting idna<3,>=2.5 (from requests~=2.25.1->torchattacks->-r requirements.txt (line 12))
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting urllib3<1.27,>=1.21.1 (from requests~=2.25.1->torchattacks->-r requirements.txt (line 12))
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests~=2.25.1->torchattacks->-r requirements.txt (line 12)) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (0.24.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 13)) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam->-r requirements.txt (line 15)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam->-r requirements.txt (line 15)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam->-r requirements.txt (line 15)) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam->-r requirements.txt (line 15)) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam->-r requirements.txt (line 15)) (3.3.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 2)) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm->-r requirements.txt (line 2)) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm->-r requirements.txt (line 2)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm->-r requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->timm->-r requirements.txt (line 2)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->timm->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->timm->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->timm->-r requirements.txt (line 2)) (0.1.2)
# Downloading medmnist-3.0.2-py3-none-any.whl (25 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 16.0 MB/s eta 0:00:00
# Downloading torchattacks-3.5.1-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 18.9 MB/s eta 0:00:00
# Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 7.9 MB/s eta 0:00:00
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 20.2 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 21.1 MB/s eta 0:00:00
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: fvcore, grad-cam, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=c76b7c2018b2f3db06d0bf6012f0c60f8e8f3eac530f3e9d8032bf161460091e
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
#   Building wheel for grad-cam (pyproject.toml) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.5.5-py3-none-any.whl size=44286 sha256=9b7e644070eb093d99f9f440c87688f147202b950cd1855d8838f63ee68b6ba1
#   Stored in directory: /root/.cache/pip/wheels/fb/3b/09/2afc520f3d69bc26ae6bd87416759c820a3f7d05c1a077bbf6
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=3db0ff708e30a66270bb338a5c385f534e0aff49d4fdd6cec7b8993d8e263946
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built fvcore grad-cam iopath
# Installing collected packages: yacs, urllib3, ttach, portalocker, idna, fire, chardet, requests, iopath, fvcore, torchattacks, medmnist, grad-cam
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.25.1 which is incompatible.
# datasets 4.0.0 requires requests>=2.32.2, but you have requests 2.25.1 which is incompatible.
# google-genai 1.66.0 requires requests<3.0.0,>=2.28.1, but you have requests 2.25.1 which is incompatible.
# tweepy 4.16.0 requires requests<3,>=2.27.0, but you have requests 2.25.1 which is incompatible.
# libpysal 4.14.1 requires requests>=2.32.0, but you have requests 2.25.1 which is incompatible.
# pysal 25.7 requires requests>=2.27, but you have requests 2.25.1 which is incompatible.
# tiktoken 0.12.0 requires requests>=2.26.0, but you have requests 2.25.1 which is incompatible.
# google-adk 1.26.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.25.1 which is incompatible.
# sphinx 8.2.3 requires requests>=2.30.0, but you have requests 2.25.1 which is incompatible.
# bigframes 2.37.0 requires requests>=2.27.1, but you have requests 2.25.1 which is incompatible.
# blobfile 3.2.0 requires urllib3>=2, but you have urllib3 1.26.20 which is incompatible.
# yfinance 0.2.66 requires requests>=2.31, but you have requests 2.25.1 which is incompatible.
# Successfully installed chardet-4.0.0 fire-0.7.1 fvcore-0.1.5.post20221221 grad-cam-1.5.5 idna-2.10 iopath-0.1.10 medmnist-3.0.2 portalocker-3.2.0 requests-2.25.1 torchattacks-3.5.1 ttach-0.0.3 urllib3-1.26.20 yacs-0.1.8

# %%
# !pip install --upgrade requests urllib3
# !pip install -r requirements.txt --no-deps
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.25.1)
# Collecting requests
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (1.26.20)
# Collecting urllib3
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 3.9 MB/s eta 0:00:00
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 10.5 MB/s eta 0:00:00
# Installing collected packages: urllib3, requests
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.20
#     Uninstalling urllib3-1.26.20:
#       Successfully uninstalled urllib3-1.26.20
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchattacks 3.5.1 requires requests~=2.25.1, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Successfully installed requests-2.32.5 urllib3-2.6.3
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.0.25)
# Requirement already satisfied: medmnist==3.0.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.25.2)
# Requirement already satisfied: fvcore in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.1.5.post20221221)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.67.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (11.3.0)
# Requirement already satisfied: fire in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: torchattacks in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (3.5.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (0.25.0+cu128)
# Requirement already satisfied: grad-cam in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (1.5.5)
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (1.5.1)

# %% [markdown]
# **Important!!!**
#
# Before installing the natten module, check the PyTorch version in Colab. Then, install the appropriate version from the following link:
# https://shi-labs.com/natten/

# %%
import torch

print(torch.__version__)
# Out:
# 2.10.0+cu128

# %%
# !pip install natten==0.21.5+torch2100cu128 -f https://whl.natten.org
# Out:
# Looking in links: https://whl.natten.org
# Collecting natten==0.21.5+torch2100cu128
#   Downloading https://github.com/SHI-Labs/NATTEN/releases/download/v0.21.5/natten-0.21.5%2Btorch2100cu128-cp312-cp312-linux_x86_64.whl (367.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.9/367.9 MB 4.5 MB/s eta 0:00:00
# Installing collected packages: natten
# Successfully installed natten-0.21.5+torch2100cu128

# %%
from main import download_checkpoint

url = "https://dl.dropbox.com/scl/fi/owujijpsl6vwd481hiydd/MedViT_large.pth?rlkey=cx9lqb4a1288nv4xlmux13zoe&st=kcehwbrb&dl=0"
path = 'MedViT_large_breastmnist.pth'
download_checkpoint(url, path)
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Downloading checkpoint from https://dl.dropbox.com/scl/fi/owujijpsl6vwd481hiydd/MedViT_large.pth?rlkey=cx9lqb4a1288nv4xlmux13zoe&st=kcehwbrb&dl=0...
# Checkpoint downloaded and saved to MedViT_large_breastmnist.pth

# %%
# !python Heatmap/GradCam_MedViT_large.py --dataset breastmnist --image-path 'Fig/breastmnist.png'
# Out:
# Traceback (most recent call last):
#   File "/content/MedViTV2/Heatmap/GradCam_MedViT_large.py", line 23, in <module>
#     from MedViT import MedViT_tiny, MedViT_small, MedViT_small, MedViT_large
# ModuleNotFoundError: No module named 'MedViT'

# %%
import cv2
from google.colab.patches import cv2_imshow

# Define the saved image path
image_path = 'large_breastmnist_cam.jpg'

# Read and display the image
image = cv2.imread(image_path)
cv2_imshow(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_26228/3788941671.py in <cell line: 0>()
#       7 # Read and display the image
#       8 image = cv2.imread(image_path)
# ----> 9 cv2_imshow(image)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'
