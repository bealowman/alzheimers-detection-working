# %% [markdown]
# #MedViTV2
#
# For training and evaluating the model, it is recommended to use a GPU due to the high computational requirements.

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
pip install torch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Collecting torch==2.5.0
#   Downloading https://download.pytorch.org/whl/cu124/torch-2.5.0%2Bcu124-cp312-cp312-linux_x86_64.whl (908.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.2 MB/s eta 0:00:00
# Collecting torchvision==0.20.0
#   Downloading https://download-r2.pytorch.org/whl/cu124/torchvision-0.20.0%2Bcu124-cp312-cp312-linux_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 75.7 MB/s eta 0:00:00
# Collecting torchaudio==2.5.0
#   Downloading https://download-r2.pytorch.org/whl/cu124/torchaudio-2.5.0%2Bcu124-cp312-cp312-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 96.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.1 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.21.5 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.7 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.9 MB/s eta 0:00:00
# Collecting triton==3.1.0 (from torch==2.5.0)
#   Downloading https://download.pytorch.org/whl/triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (75.2.0)
# Collecting sympy==1.13.1 (from torch==2.5.0)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision==0.20.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.20.0) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch==2.5.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.5.0) (3.0.3)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 51.2 MB/s eta 0:00:00
# Installing collected packages: triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.29.7
#     Uninstalling nvidia-nccl-cu12-2.29.7:
#       Successfully uninstalled nvidia-nccl-cu12-2.29.7
#   Attempting uninstall: torch
#     Found existing installation: torch 2.10.0+cpu
#     Uninstalling torch-2.10.0+cpu:
#       Successfully uninstalled torch-2.10.0+cpu
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.25.0+cpu
#     Uninstalling torchvision-0.25.0+cpu:
#       Successfully uninstalled torchvision-0.25.0+cpu
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.10.0+cpu
#     Uninstalling torchaudio-2.10.0+cpu:
#       Successfully uninstalled torchaudio-2.10.0+cpu
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grad-cam 1.5.5 requires ttach, which is not installed.
# torchattacks 3.5.1 requires requests~=2.25.1, but you have requests 2.33.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 sympy-1.13.1 torch-2.5.0+cu124 torchaudio-2.5.0+cu124 torchvision-0.20.0+cu124 triton-3.1.0

# %%
# !pip install natten==0.17.5+torch250cu124 -f https://whl.natten.org
# Out:
# Looking in links: https://whl.natten.org
# Collecting natten==0.17.5+torch250cu124
#   Downloading https://github.com/SHI-Labs/NATTEN/releases/download/v0.17.5/natten-0.17.5%2Btorch250cu124-cp312-cp312-linux_x86_64.whl (474.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.7/474.7 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from natten==0.17.5+torch250cu124) (26.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from natten==0.17.5+torch250cu124) (2.10.0+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->natten==0.17.5+torch250cu124) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->natten==0.17.5+torch250cu124) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->natten==0.17.5+torch250cu124) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->natten==0.17.5+torch250cu124) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->natten==0.17.5+torch250cu124) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->natten==0.17.5+torch250cu124) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->natten==0.17.5+torch250cu124) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->natten==0.17.5+torch250cu124) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->natten==0.17.5+torch250cu124) (3.0.3)
# Installing collected packages: natten
# Successfully installed natten-0.17.5+torch250cu124

# %% [markdown]
# To get started, clone the repository and navigate to the project directory:

# %%
import os
if not os.path.exists('/content/alzheimers-detection-working'):
    # !git clone https://github.com/bealowman/alzheimers-detection-working
# Out:
# Cloning into 'alzheimers-detection-working'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 98 (delta 24), reused 79 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 2.53 MiB | 11.38 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
# %cd /content/alzheimers-detection-working/MedViTV2-main
# Out:
# /content/alzheimers-detection-working/MedViTV2-main

# %%
# !git checkout bea
# Out:
# Branch 'bea' set up to track remote branch 'bea' from 'origin'.
# Switched to a new branch 'bea'

# %%
# !pip install --upgrade requests urllib3
# !pip install -r requirements.txt --no-deps
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.33.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.0.25)
# Requirement already satisfied: medmnist==3.0.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.25.2)
# Requirement already satisfied: fvcore in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.1.5.post20221221)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.67.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (11.3.0)
# Requirement already satisfied: fire in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: torchattacks in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (3.5.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (2.5.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (0.20.0+cu124)
# Requirement already satisfied: grad-cam in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (1.5.5)
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (1.5.1)

# %% [markdown]
# ### 🧠 Train Different Versions of MedViT on 17 Datasets
#
# You can easily train different versions of MedViT by specifying the model and dataset names:
#
#  🔹 **Model Selection:**
# ```bash
# --model_name [MedViT_tiny, MedViT_small, MedViT_base, MedViT_large]

# %% [markdown]
#
#
#  📊 **Dataset Selection:**
# ```bash
# --dataset [tissuemnist, pathmnist, chestmnist, dermamnist, octmnist,
#            pneumoniamnist, retinamnist, breastmnist, bloodmnist,
#            organamnist, organcmnist, organsmnist, Kvasir, CPN,
#            Fetal, PAD, ISIC2018]

# %%
from google.colab import drive
drive.mount("/content/drive")

import os
os.environ["DEMENTIA_DATASET_DIR"] = "/content/drive/MyDrive/SP26_dementia_data/processed_data"
# Out:
# Mounted at /content/drive

# %% [markdown]
# !!!! The process of downloading the dataset for the first time may take a while, so please be patient. 😊

# %%
# !python main.py --model_name 'MedViT_tiny' --dataset 'Dementia' --pretrained True
# Out:
# Traceback (most recent call last):
#   File "/content/alzheimers-detection-working/MedViTV2-main/main.py", line 24, in <module>
#     import natten
#   File "/usr/local/lib/python3.12/dist-packages/natten/__init__.py", line 69, in <module>
#     from .na1d import NeighborhoodAttention1D
#   File "/usr/local/lib/python3.12/dist-packages/natten/na1d.py", line 30, in <module>
#     from .experimental import na1d as experimental_na1d
#   File "/usr/local/lib/python3.12/dist-packages/natten/experimental.py", line 106, in <module>
#     from .ops import additional_sdpa, merge_attentions
#   File "/usr/local/lib/python3.12/dist-packages/natten/ops.py", line 29, in <module>
#     from .utils.testing import _IS_TORCH_COMPILE_SUPPORTED
#   File "/usr/local/lib/python3.12/dist-packages/natten/utils/testing.py", line 47, in <module>
#     _IS_TRITON_SUPPORTED = get_device_cc() >= 70
#                            ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/natten/utils/misc.py", line 31, in get_device_cc
#     major, minor = torch.cuda.get_device_capability(device_index)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 509, in get_device_capability
#     prop = get_device_properties(device)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 523, in get_device_properties
#     _lazy_init()  # will define _get_device_properties
#     ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 319, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %% [markdown]
# ###Train timm models
# 🤯 You can easily train any model from TIMM on each dataset by simply changing the model name. If a pre-trained version is available, you can enable it by setting the corresponding flag to True.
#
# link: https://timm.fast.ai/

# %%
# !python main.py --model_name 'resnet34' --dataset 'octmnist' --pretrained True
