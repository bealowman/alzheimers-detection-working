# %% [markdown]
# #MedViTV2
#
# For training and evaluating the model, it is recommended to use a GPU due to the high computational requirements.

# %%
# !nvidia-smi

# %%
pip install torch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 --index-url https://download.pytorch.org/whl/cu124

# %%
# !pip install natten==0.17.5+torch250cu124 -f https://whl.natten.org

# %% [markdown]
# To get started, clone the repository and navigate to the project directory:

# %%
import os
if not os.path.exists('/content/alzheimers-detection-working'):
    # !git clone https://github.com/your/repo.git /content/alzheimers-detection-working
os.chdir('/content/alzheimers-detection-working')

# %%
# %cd /content/alzheimers-detection-working/MedViTV2-main
# Out:
# /content/alzheimers-detection-working/MedViTV2-main

# %%
# !git checkout bea
# Out:
# Branch 'bea' set up to track remote branch 'bea' from 'origin'.
# Switched to a new branch 'bea'

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### 🧠 Train Different Versions of MedViT on 17 Datasets
#
# You can easily train different versions of MedViT by specifying the model and dataset names:
#
#  🔹 **Model Selection:**
# ```bash
# --model_name [MedViT_tiny, MedViT_small, MedViT_base, MedViT_large]

# %% [markdown]
#
#
#  📊 **Dataset Selection:**
# ```bash
# --dataset [tissuemnist, pathmnist, chestmnist, dermamnist, octmnist,
#            pneumoniamnist, retinamnist, breastmnist, bloodmnist,
#            organamnist, organcmnist, organsmnist, Kvasir, CPN,
#            Fetal, PAD, ISIC2018]

# %%
from google.colab import drive
drive.mount("/content/drive")

import os
os.environ["DEMENTIA_DATASET_DIR"] = "/content/drive/MyDrive/SP26_dementia_data/processed_data"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# !!!! The process of downloading the dataset for the first time may take a while, so please be patient. 😊

# %%
# !python main.py --model_name 'MedViT_tiny' --dataset 'Dementia' --pretrained True
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Using cuda:0 device.
# Copying Dementia train split: /content/drive/MyDrive/SP26_dementia_data/processed_data/train -> data/Dementia-Dataset/train
# Train copy complete.
# Copying Dementia val split: /content/drive/MyDrive/SP26_dementia_data/processed_data/val -> data/Dementia-Dataset/val
# Val copy complete.
# Dementia dataset is available at: train=data/Dementia-Dataset/train val=data/Dementia-Dataset/val
# initialize_weights...
# Downloading checkpoint from https://dl.dropbox.com/scl/fi/496jbihqp360jacpji554/MedViT_tiny.pth?rlkey=6hb9froxugvtg8l639jmspxfv&st=p9ef06j8&dl=0...
# Checkpoint downloaded and saved to ./MedViT_tiny.pth
# /content/alzheimers-detection-working/MedViTV2-main/main.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)
# Dataset ImageFolder
#     Number of datapoints: 30799
#     Root location: data/Dementia-Dataset/train
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear, antialias=True)
#                AugMix(severity=3, mixture_width=3, chain_depth=-1, alpha=0.4, all_ops=True, interpolation=InterpolationMode.BILINEAR, fill=None)
#                RandomHorizontalFlip(p=0.4)
#                ToTensor()
#                Normalize(mean=[0.5], std=[0.5])
#            )
# ===================
# Dataset ImageFolder
#     Number of datapoints: 6600
#     Root location: data/Dementia-Dataset/val
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#                Normalize(mean=[0.5], std=[0.5])
#            )
# train epoch[1/100] loss:1.397: 100% 1284/1284 [15:28<00:00,  1.38it/s]
# 100% 138/138 [00:45<00:00,  3.02it/s]
# [epoch 1] train_loss: 1.255 val_accuracy: 0.5197 precision: 0.5187 recall: 0.5197 specificity: 0.8402 f1_score: 0.5136 auc: 0.7818 overall_accuracy: 0.5197
#
# Saving checkpoint...
# train epoch[2/100] loss:1.832: 100% 1284/1284 [15:34<00:00,  1.37it/s]
# 100% 138/138 [00:45<00:00,  3.05it/s]
# [epoch 2] train_loss: 1.092 val_accuracy: 0.6042 precision: 0.6397 recall: 0.6042 specificity: 0.8683 f1_score: 0.5977 auc: 0.8467 overall_accuracy: 0.6042
#
# Saving checkpoint...
# train epoch[3/100] loss:1.286: 100% 1284/1284 [15:31<00:00,  1.38it/s]
# 100% 138/138 [00:45<00:00,  3.06it/s]
# [epoch 3] train_loss: 0.966 val_accuracy: 0.6461 precision: 0.6393 recall: 0.6461 specificity: 0.8810 f1_score: 0.6302 auc: 0.8690 overall_accuracy: 0.6461
#
# Saving checkpoint...
# train epoch[4/100] loss:1.025: 100% 1284/1284 [15:34<00:00,  1.37it/s]
# 100% 138/138 [00:45<00:00,  3.06it/s]
# [epoch 4] train_loss: 0.900 val_accuracy: 0.6759 precision: 0.6810 recall: 0.6759 specificity: 0.8916 f1_score: 0.6763 auc: 0.8855 overall_accuracy: 0.6759
#
# Saving checkpoint...
# train epoch[5/100] loss:1.306: 100% 1284/1284 [15:48<00:00,  1.35it/s]
# 100% 138/138 [00:45<00:00,  3.01it/s]
# [epoch 5] train_loss: 0.844 val_accuracy: 0.6820 precision: 0.6727 recall: 0.6820 specificity: 0.8924 f1_score: 0.6727 auc: 0.8889 overall_accuracy: 0.6820
#
# Saving checkpoint...
# train epoch[6/100] loss:0.684: 100% 1284/1284 [15:39<00:00,  1.37it/s]
# 100% 138/138 [00:45<00:00,  3.06it/s]
# [epoch 6] train_loss: 0.810 val_accuracy: 0.6944 precision: 0.6918 recall: 0.6944 specificity: 0.8956 f1_score: 0.6838 auc: 0.9048 overall_accuracy: 0.6944
#
# Saving checkpoint...
# train epoch[7/100] loss:1.246: 100% 1284/1284 [15:47<00:00,  1.36it/s]
# 100% 138/138 [00:45<00:00,  3.05it/s]
# [epoch 7] train_loss: 0.770 val_accuracy: 0.7206 precision: 0.7535 recall: 0.7206 specificity: 0.9051 f1_score: 0.7238 auc: 0.9197 overall_accuracy: 0.7206
#
# Saving checkpoint...
# train epoch[8/100] loss:0.747: 100% 1284/1284 [15:41<00:00,  1.36it/s]
# 100% 138/138 [00:44<00:00,  3.07it/s]
# [epoch 8] train_loss: 0.740 val_accuracy: 0.7444 precision: 0.7478 recall: 0.7444 specificity: 0.9126 f1_score: 0.7421 auc: 0.9289 overall_accuracy: 0.7444
#
# Saving checkpoint...
# train epoch[9/100] loss:0.659: 100% 1284/1284 [15:44<00:00,  1.36it/s]
# 100% 138/138 [00:45<00:00,  3.06it/s]
# [epoch 9] train_loss: 0.700 val_accuracy: 0.7832 precision: 0.7790 recall: 0.7832 specificity: 0.9267 f1_score: 0.7795 auc: 0.9438 overall_accuracy: 0.7832
#
# Saving checkpoint...
# train epoch[10/100] loss:0.962: 100% 1284/1284 [15:45<00:00,  1.36it/s]
# 100% 138/138 [00:45<00:00,  3.06it/s]
# [epoch 10] train_loss: 0.687 val_accuracy: 0.7955 precision: 0.8050 recall: 0.7955 specificity: 0.9318 f1_score: 0.7931 auc: 0.9486 overall_accuracy: 0.7955
#
# Saving checkpoint...
# train epoch[11/100] loss:0.574: 100% 1284/1284 [15:49<00:00,  1.35it/s]
# 100% 138/138 [00:44<00:00,  3.07it/s]
# [epoch 11] train_loss: 0.652 val_accuracy: 0.8042 precision: 0.8048 recall: 0.8042 specificity: 0.9331 f1_score: 0.8018 auc: 0.9525 overall_accuracy: 0.8042
#
# Saving checkpoint...
# train epoch[12/100] loss:0.869: 100% 1284/1284 [15:56<00:00,  1.34it/s]
# 100% 138/138 [00:46<00:00,  2.98it/s]
# [epoch 12] train_loss: 0.624 val_accuracy: 0.7762 precision: 0.8004 recall: 0.7762 specificity: 0.9232 f1_score: 0.7753 auc: 0.9531 overall_accuracy: 0.7762
# train epoch[13/100] loss:0.605: 100% 1284/1284 [16:00<00:00,  1.34it/s]
# 100% 138/138 [00:45<00:00,  3.05it/s]
# [epoch 13] train_loss: 0.601 val_accuracy: 0.8377 precision: 0.8404 recall: 0.8377 specificity: 0.9446 f1_score: 0.8385 auc: 0.9661 overall_accuracy: 0.8377
#
# Saving checkpoint...
# train epoch[14/100] loss:0.420:  85% 1087/1284 [13:30<02:27,  1.33it/s]

# %% [markdown]
# ###Train timm models
# 🤯 You can easily train any model from TIMM on each dataset by simply changing the model name. If a pre-trained version is available, you can enable it by setting the corresponding flag to True.
#
# link: https://timm.fast.ai/

# %%
# !python main.py --model_name 'resnet34' --dataset 'octmnist' --pretrained True
